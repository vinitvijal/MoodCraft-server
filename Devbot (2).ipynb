# %%
# !pip install discord
# !pip install git+https://github.com/huggingface/transformers.git@main accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.7 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/huggingface/transformers.git (to revision main) to /tmp/pip-req-build-hnvxffsl
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-hnvxffsl
#   Resolved https://github.com/huggingface/transformers.git to commit cc3e4781854a52cf090ffde28d884a527dab6708
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 26.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 88.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.2 MB/s eta 0:00:00
# ...

# %%
import discord
import nest_asyncio
from googlesearch import search
from bs4 import BeautifulSoup as bs
import requests
import random

TOKEN="" #hidden for privacy
nest_asyncio.apply()

# %%
from transformers import AutoTokenizer
import transformers
import torch

model = "codellama/CodeLlama-7b-hf"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
def codeGeneration(text):
  sequences = pipeline(
    text,
    do_sample=True,
    top_k=10,
    temperature=0.2,
    top_p=0.9,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
  )
  return sequences

# %%
class ErrorSolver:
    def __init__(self, text):
        self.text=text + " site:stackoverflow.com"
        self.url=[]
        self.page=""
        self.soup=""
        self.answer=""
        self.f=""

    def get_question(self):
        l1=[]
        for i in self.url:
            l1.append(" ".join(i.split("/")[-1].split("-")))
        return l1

    def get_url(self):
        for i in search(self.text, tld="com", num=10, stop=5, pause=2):
            if "https://stackoverflow.com/questions/" in i:
                self.url.append(i)
                # break
        if self.url=="":
            print("No such question found")
            return False
        else:
            print("Question found")
            return True

    def get_answer(self,index=0):
        self.page=requests.get(self.url[index])
        self.soup=bs(self.page.content,'html.parser')
        self.f=open('solution.txt','w')
        self.answer=self.soup.find_all('div',class_='s-prose js-post-body')
        try:
            for i in range(1,4):
                self.f.write(self.answer[i].text)

                print((self.answer[i].text).strip())
                print("***************")
                self.f.write("\n\n\n**************\n\n\n")
        except IndexError:
            print("Number of answers are less than 3")
        finally:
            self.f.close()

# %%
noFound = ["Greetings! 👋 It seems like your question needs a bit more clarity for me to provide the best help. Please specify the problem you're facing or paste any error messages you've received in your terminal. Let's join forces and tackle this together! 🚀","Hello! 👋 It looks like we need a bit more information to assist you effectively. Could you please elaborate on your issue or share any error messages you've encountered in the terminal? Your code snippets would also be incredibly helpful. Let's crack this puzzle! 🧩","Howdy! 👋 Your question is almost there, but a little more detail could go a long way in finding the perfect solution. Don't hesitate to describe the problem more precisely or copy-paste any error messages from your terminal. We're in this together! 💪"]
greetings = ["hello","hi","hey","hey there","hi there","hello there","greetings","good day","howdy","howdy do","hey what's up","hey how are you","hey how's everything","long time no see","hey stranger","see you","yo","aloha","hola","salut","bonjour","ciao","namaste","salaam","shalom","g'day"]
welcomeToGreeting = [
    '''
    Hello! 👋 Welcome to DevBot, your code companion on this coding adventure! 🤖
Got a coding puzzle to solve or need help squashing those pesky bugs? Just drop your question, and I'll work my magic! ✨
If you're looking for guidance, type !help.
To tackle an error, type !error.
For a code boost, type !generate.
I'm here to learn and grow with you, so let's dive into the code and create something amazing! 🚀

''',

    '''Howdy! 🤠 Ready to rock your code? Here's the plan:

# !help => I'm your coding sidekick 🦸
# !error: [Describe your error] => Let's squash those bugs! 🐞
# !gen: [Explain your problem] => Time to whip up some magic! 🪄

Let's dive into code wonderland! 🚀''',


'''Hiya! 🌈 Excited to code with you! Remember the magic words:

# !help => For your coding spells 🪄
# !error: [Spill the error beans] => Let's work some wizardry! 🧙
# !gen: [Spell out your problem] => Conjuring code just for you! 💫

Let's make some enchanting code! 🚀
''',

    '''
    Greetings, coder! 🚀 Ready for coding awesomeness? Let's roll:

# !help => Your code genie at your service 🧞
# !error: [Describe that tricky error] => Time to conquer! ⚔️
# !gen: [State your coding quest] => Crafting code potions! 🧪

Let's create some code magic! 🪄
''',

    '''
    Heya, champ! 💪 Ready to code like a boss? Follow the code map:

# !help => Your trusty code compass 🧭
# !error: [Unleash the error beast] => Let's tame it! 🦁
# !gen: [Express your coding quest] => Brewing code excellence! ☕

Let's conquer the code realm! 🌌''',

    '''Yo, coder pal! 🌟 Let's make some code waves! Here's the deal:

# !help => Your code lifeguard on duty 🏊
# !error: [Spill the error beans] => Ready to be the error terminator? 🔥
# !gen: [Outline your coding epic] => Crafting your code saga! 📜

Let's sail through the code seas! ⛵''',

'''
Hey, hey! 🎉 Ready to crack the code? Here's your treasure map:

# !help => Your code treasure guide 🗺️
# !error: [Describe the error monster] => Time to be the error slayer! ⚔️
# !gen: [Share your coding quest] => Brewing code potions! 🧪

Let's embark on a code adventure! 🚢

''',
    '''G'day, code explorer! 🌄 Ready for a coding safari? Here's your gear:

# !help => Your coding compass 🧭
# !error: [Spot the error in the wild] => Let's go error hunting! 🦁
# !gen: [Define your coding expedition] => Crafting code expeditions! 🌿

Let's venture into the coding wilderness! 🐾
''',

    '''Ahoy, matey! ☠️ Ready to navigate the code seas? Here's your ship:

# !help => Your code navigator's log 📜
# !error: [Describe the error sea monster] => Ready the cannons! 💣
# !gen: [Outline your coding odyssey] => Crafting code legends! 🗺️

Let's sail the code seas and find hidden treasures! 🏴‍☠️


''',

    '''Greetings, coding wizard! 🧙‍♂️ Ready to conjure some code magic? Here's your wand:

# !help => Your magical code wand 🪄
# !error: [Unleash the error dragon] => Time to cast your spells! ✨
# !gen: [Share your magical coding quest] => Brewing code potions! 🌟

Let's create some spellbinding code! 🌌''',

    '''Aloha, code surfer! 🏄 Ready to catch the code wave? Here's your board:

# !help => Your code wave navigator 🌊
# !error: [Describe the error wave] => Ready to ride it out! 🏄‍♂️
# !gen: [Outline your coding wave] => Crafting code waves! 🏄‍♀️

Let's ride the code waves and catch some epic code curls! 🤙'''

]


default = [
    '''Hey there! 🌟 I'm here to assist you, buddy! To make the most out of our coding journey, use the following commands:
* !help => For any assistance you need 🛠️
* !error: [Type your error here] => To resolve those pesky errors 🚧
* !gen  [Provide your problem statement] => For code generation tailored to your needs 💻
Remember to start with ! and use a : to ensure I catch your command perfectly. Let's make coding smoother together! 🚀''',

    '''Greetings! 🌟 Ready to turbocharge your coding journey? Here are your commands for success:

# !help => For any assistance you need 🛠️
# !error: [Describe your error] => Let's tackle those pesky errors! 🚧
# !gen  [Explain your problem] => Tailored code generation at your service 💻

Start with ! and a : to unlock the coding magic! Let's make coding a breeze! 🚀

''',

    '''Hello, fellow coder! 🌟 Ready to optimize your code? Here's the roadmap:

# !help => For any assistance you need 🛠️
# !error: [Unleash your error] => Let's conquer those errors! 🚧
# !gen  [State your problem] => Custom code generation awaits! 💻

Remember the ! and : magic combo! Let's streamline our coding journey! 🚀''',

    '''Salutations! 🌟 Eager to elevate your coding game? Here's the secret code:

# !help => For any assistance you need 🛠️
# !error: [Expose that error] => Let's crack the error code! 🚧
# !gen  [Detail your problem] => Precision code generation unlocked! 💻

The magic starts with ! and : — let's code smarter, not harder! 🚀''',

    '''Howdy, aspiring coder! 🌟 Ready to level up your coding skills? Here's your toolkit:

# !help => For any assistance you need 🛠️
# !error: [Reveal your error] => Let's troubleshoot those pesky errors! 🚧
# !gen  [Share your problem] => Tailored code generation on demand 💻

Don't forget the ! and : for the ultimate coding journey! Let's code with finesse! 🚀''',

    '''Greetings, code maestro! 🌟 Ready to finesse your code? Here's your coding symphony:

# !help => For any assistance you need 🛠️
# !error: [Declare your error] => Let's unravel the error tapestry! 🚧
# !gen  [Narrate your problem] => Bespoke code generation just a message away 💻

Begin with ! and : to compose your coding masterpiece! Let's make sweet coding music! 🚀'''
]

noSolution = [
    "Hey there! 👋 It seems like your query is a bit unclear or missing some essential details. To assist you effectively, please provide a more specific problem description or share any error messages you've encountered in the terminal.",
    "For error-related queries, pasting the exact error message helps me pinpoint the issue better. If you can, include any relevant code snippets as well. Let's work together to solve this! 🛠️",
    "Greetings! 👋 It seems like your question needs a bit more clarity for me to provide the best help. Please specify the problem you're facing or paste any error messages you've received in your terminal. Let's join forces and tackle this together! 🚀",
    "Hello! 👋 It looks like we need a bit more information to assist you effectively. Could you please elaborate on your issue or share any error messages you've encountered in the terminal? Your code snippets would also be incredibly helpful. Let's crack this puzzle! 🧩",
    "Howdy! 👋 Your question is almost there, but a little more detail could go a long way in finding the perfect solution. Don't hesitate to describe the problem more precisely or copy-paste any error messages from your terminal. We're in this together! 💪"
]


notAbleToGenerateCode = [
    '''Hey there! 👋 Generating the perfect code for you is my mission, but sometimes I need a little more guidance. If the code generation isn't hitting the mark, it might be due to a few common hiccups:
1️⃣ **Clarity**: Ensure your problem statement is clear and specific.
2️⃣ **Details**: Include all the necessary details for accurate code generation.
3️⃣ **Complexity**: If the problem is complex, try breaking it down into simpler parts.

Feel free to rephrase or break down your problem into smaller pieces, then ask them one by one. The clearer the question, the better the code I can generate for you. Let's unravel this coding puzzle together! 🧩

''',

    '''Hello! 👋 Crafting code that fits your needs is my goal, but sometimes I need a bit more context. If the generated code isn't hitting the mark, consider:
1️⃣ **Detail**: Add as much detail as possible in your problem statement.
2️⃣ **Structure**: Break down your problem into smaller, manageable parts.
3️⃣ **Clarify**: Ensure your problem statement is clear and free of ambiguity.

Feel free to break it down and ask each part separately for a more accurate response. Your clear guidance makes all the difference! Let's tackle this coding challenge together! 🚀''',

    '''Greetings, coder! 👋 Crafting tailored code is my passion, but sometimes the path isn't clear. If the generated code isn't hitting the mark, consider:
1️⃣ **Detail**: Elaborate on your problem statement, leaving no room for confusion.
2️⃣ **Break it Down**: Divide intricate problems into smaller, manageable tasks.
3️⃣ **Clarity is Key**: Ensure your problem description is clear and concise.

Feel free to deconstruct the problem and ask for help with each piece. Your clarity sharpens my code skills! Let's unravel this coding enigma! 🧩''',

    '''Hey! 👋 Tailoring code to your needs is my forte, but I need a clear canvas. If the generated code isn't perfect, consider:
1️⃣ **Specifics**: Provide detailed specifics in your problem statement.
2️⃣ **Divide and Conquer**: Break complex problems into simpler, solvable parts.
3️⃣ **Clarity is Queen**: Ensure your problem statement is crystal clear.

Feel free to break the problem into digestible parts and ask each one separately. Your clear roadmap guides my code crafting. Let's decode this coding challenge! 🧩'''
]

# %%
client = discord.Client(intents=discord.Intents.default())
# Out:
# WARNING:discord.client:PyNaCl is not installed, voice will NOT be supported

# %%
@client.event
async def on_ready():
    print(f'{client.user} has connected to Discord!')

@client.event
async def on_message(message):
    msg = (message.content).lower()
    if message.author == client.user:
        print("Bot sent a message")
        return

    if msg in (greetings):
        embedVar = discord.Embed(title=random.choice(welcomeToGreeting), color=0x329dd3)
        await message.channel.send(embed=embedVar)

    elif msg.startswith('!help'):
        await message.channel.send('!hello - Say hello to the bot\n!roll - Roll a random number between 1 and 100\n!clear - Clear the last 100 messages\n!help - See this message again')

    elif msg.startswith('!test'):
        await message.channel.send('Test complete')

    elif msg.startswith('!gen'):
        text = msg.split('!gen')[1].strip()
        print(text)
        await message.channel.send('Wait ⚡️ We are cooking 🔥 your code!!!')
        seq = codeGeneration(text)
        await message.channel.send('Congo 🚀 Here We Are!!!')

        code = ''
        for i in seq:
            code += i['generated_text']
        # solution = (((code.split("\begin{code}"))[1]).split("\end"))[0]
        embedVar = discord.Embed(title="Here is your generated code ⚡️", color=0x00ff00)
        embedVar.add_field(name="Solution", value=code, inline=False)
        await message.channel.send(embed=embedVar)


    elif msg.startswith('!error'):


        text = message.content.split('!error')[1].strip()
        print(text)
        sol = ErrorSolver(text)
        if sol.get_url():
            sol.get_answer()
            await message.channel.send("I have found the following answers on StackOverflow:")
            await message.channel.send(file=discord.File('solution.txt'))
            await message.channel.send(sol.get_question())
            print(sol.get_question())
            embedVar = discord.Embed(title="Alternative Solutions", color=0x00ff00)

            for i,e in enumerate(sol.get_question()):
                # await message.channel.send(i+1, e)
                embedVar.add_field(name="Similiar Error {index}".format(index = i+1), value=e, inline=False)
            await message.channel.send(embed=embedVar)
            # for i,e in enumerate(sol.get_question()):
            #     await message.channel.send(i,'. ', e)
            await message.channel.send("\n\nWhich answer would you like to see? Write \n\n!error 'i am alternative error'")

            try:
                def check(response):
                    return response.author == message.author and response.channel == message.channel
                response = await client.wait_for('message', check=check, timeout=60)
                index = int(response.content)
                sol.get_answer(index)

                await message.channel.send(file=discord.File('solution.txt'))

            except asyncio.TimeoutError:
                await message.channel.send("You took too long to respond.\n\n")
        else:
            await message.channel.send(random.choice(noSolution))
    else:
      await message.channel.send(random.choice(default))
client.run(TOKEN)
# Out:
# 2023-11-05 00:26:57 INFO     discord.client logging in using static token
# INFO:discord.client:logging in using static token
# 2023-11-05 00:26:59 INFO     discord.gateway Shard ID None has connected to Gateway (Session ID: f5b16436039c8b3cb4e04516b8360a2a).
# INFO:discord.gateway:Shard ID None has connected to Gateway (Session ID: f5b16436039c8b3cb4e04516b8360a2a).
# DevBuddy#1010 has connected to Discord!
# 2023-11-05 00:27:15 ERROR    discord.client Ignoring exception in on_message
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/discord/client.py", line 441, in _run_event
#     await coro(*args, **kwargs)
#   File "<ipython-input-8-73dff54802ce>", line 14, in on_message
#     await message.channel.send(embed=embedVar)
#   File "/usr/local/lib/python3.10/dist-packages/discord/abc.py", line 1561, in send
#     data = await state.http.send_message(channel.id, params=params)
# ...
